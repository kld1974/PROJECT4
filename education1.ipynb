# %% [markdown]
# # Project 4
#
# Create code to answer each of the following questions.
#
# > Project Description/Outline: This project will look at the data on

# %%
#Importing Dependencies:
#%matplotlib inline
import numpy as np
import pandas as pd
#import matplotlib.pyplot as plt
#import matplotlib as mpl

# %%
#Reading data :
edu_df = pd.read_csv("Resources/df.csv")

# %%
edu_df.head(20)
# Out:
#         ID                                 Name    State     Region  \
# 0   100654             Alabama A & M University  Alabama  Southeast
# 1   100663  University of Alabama at Birmingham  Alabama  Southeast
# 2   100706  University of Alabama in Huntsville  Alabama  Southeast
# 3   100724             Alabama State University  Alabama  Southeast
# 4   100751            The University of Alabama  Alabama  Southeast
# 5   100830      Auburn University at Montgomery  Alabama  Southeast
# 6   100858                    Auburn University  Alabama  Southeast
# 7   100937          Birmingham-Southern College  Alabama  Southeast
# 8   101189                  Faulkner University  Alabama  Southeast
# 9   101435                   Huntingdon College  Alabama  Southeast
# 10  101480        Jacksonville State University  Alabama  Southeast
# 11  101587           University of West Alabama  Alabama  Southeast
# 12  101693                 University of Mobile  Alabama  Southeast
# ...

# %%
edu_clean_df = edu_df.rename(columns={"SATVR75" : "SAT Verbal Read 75",
                                     "SATMT75" : "SAT Math 75",
                                     "ACTEN75" : "ACT English 75",
                                     "ACTMT75" : "ACT Math 75"}
                                    )
edu_clean_df.columns
# Out:
# Index(['ID', 'Name', 'State', 'Region', 'Applications', 'Admissions',
#        'Admission Rate', 'Enrollment', 'SAT Verbal Read 75', 'SAT Math 75',
#        'ACT English 75', 'ACT Math 75'],
#       dtype='object')

# %%
edu_clean_df = edu_clean_df.fillna(0)
edu_clean_df.head(10)
# Out:
#        ID                                 Name    State     Region  \
# 0  100654             Alabama A & M University  Alabama  Southeast
# 1  100663  University of Alabama at Birmingham  Alabama  Southeast
# 2  100706  University of Alabama in Huntsville  Alabama  Southeast
# 3  100724             Alabama State University  Alabama  Southeast
# 4  100751            The University of Alabama  Alabama  Southeast
# 5  100830      Auburn University at Montgomery  Alabama  Southeast
# 6  100858                    Auburn University  Alabama  Southeast
# 7  100937          Birmingham-Southern College  Alabama  Southeast
# 8  101189                  Faulkner University  Alabama  Southeast
# 9  101435                   Huntingdon College  Alabama  Southeast
#
#    Applications  Admissions  Admission Rate  Enrollment  SAT Verbal Read 75  \
# 0          6560        4697        0.716006        1459               520.0
# ...

# %%
school_types_df = edu_clean_df.set_index(["Region"])
school_types_df
# Out:
#                  ID                                 Name         State  \
# Region
# Southeast    100654             Alabama A & M University       Alabama
# Southeast    100663  University of Alabama at Birmingham       Alabama
# Southeast    100706  University of Alabama in Huntsville       Alabama
# Southeast    100724             Alabama State University       Alabama
# Southeast    100751            The University of Alabama       Alabama
# ...             ...                                  ...           ...
# New England  487524                    Husson University         Maine
# Far West     490133                 Westcliff University    California
# Great Lakes  490805          Purdue University Northwest       Indiana
# Mid East     495767    The Pennsylvania State University  Pennsylvania
# Southeast    496681           Florida Academy of Nursing       Florida
#
#              Applications  Admissions  Admission Rate  Enrollment  \
# Region
# ...

# %%
school_types_df=school_types_df.drop("Other US Jurisdctn")
school_types_df=school_types_df.drop ("US Service Schools")
school_types_df
# Out:
#                  ID                                 Name         State  \
# Region
# Southeast    100654             Alabama A & M University       Alabama
# Southeast    100663  University of Alabama at Birmingham       Alabama
# Southeast    100706  University of Alabama in Huntsville       Alabama
# Southeast    100724             Alabama State University       Alabama
# Southeast    100751            The University of Alabama       Alabama
# ...             ...                                  ...           ...
# New England  487524                    Husson University         Maine
# Far West     490133                 Westcliff University    California
# Great Lakes  490805          Purdue University Northwest       Indiana
# Mid East     495767    The Pennsylvania State University  Pennsylvania
# Southeast    496681           Florida Academy of Nursing       Florida
#
#              Applications  Admissions  Admission Rate  Enrollment  \
# Region
# ...

# %%
school_types_df.dtypes
# Out:
# ID                      int64
# Name                   object
# State                  object
# Applications            int64
# Admissions              int64
# Admission Rate        float64
# Enrollment              int64
# SAT Verbal Read 75    float64
# SAT Math 75           float64
# ACT English 75        float64
# ACT Math 75           float64
# dtype: object

# %%
school_types_df.to_csv("education_cleaned.csv", encoding='utf8', index=False)

# %%
edu_clean_df=school_types_df.reset_index
edu_clean_df()
# Out:
#            Region      ID                                 Name         State  \
# 0       Southeast  100654             Alabama A & M University       Alabama
# 1       Southeast  100663  University of Alabama at Birmingham       Alabama
# 2       Southeast  100706  University of Alabama in Huntsville       Alabama
# 3       Southeast  100724             Alabama State University       Alabama
# 4       Southeast  100751            The University of Alabama       Alabama
# ...           ...     ...                                  ...           ...
# 1350  New England  487524                    Husson University         Maine
# 1351     Far West  490133                 Westcliff University    California
# 1352  Great Lakes  490805          Purdue University Northwest       Indiana
# 1353     Mid East  495767    The Pennsylvania State University  Pennsylvania
# 1354    Southeast  496681           Florida Academy of Nursing       Florida
#
# ...

# %%
#edu_clean_df.to_csv("Resources/educationcleaned2.csv", encoding='utf8', index=False)
